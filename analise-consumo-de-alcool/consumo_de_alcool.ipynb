# %% [markdown]
# # Análise do consumo de álcool no mundo

# %% [markdown]
# Os dados são referentes ao consumo de álcool por pessoa em diferentes países, coletados pela Organização Mundial da Saúde (OMS) no ano de 2010. Indicam o consumo de cerveja (beer), licor (spirit) e vinho (wine), e o consumo de litros de álcool por pessoa do país no ano de 2010. O dataset possui 5 colunas: uma variável categórica, o nome do país, e quatro variáveis quantitativas, que são quantidade de latas de cerveja, doses de licor, taças de vinho e a quantidade total de litros de álcool consumido por pessoa em cada país em determinado ano.
#
# Serão respondidas as seguintes perguntas sobre os dados que irão ajudar a compor o relatório:
#
#
# 1. Qual a média e desvio padrão do consumo de cerveja, licor, vinho e total de álcool?
#
# 2. Qual o consumo de licor na França?
#
# 3. Quais os 5 países nos quais se consome mais cerveja?
#
# 4. Quais os 5 países nos quais se consome mais licor?
#
# 5. Quais os 5 países nos quais se consome mais vinho?
#
# 6. Quais os países nos quais o consumo de cerveja está acima da média?
#
# 7. Quais países nos quais o consumo total de álcool está acima do Brasil, em ordem crescente?
#
# 8. De acordo com o conjunto de dados, 5 países com o consumo total de álcool igual a zero.
#
# 9. Gráfico com os 10 maiores consumidores de álcool.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df = pd.read_csv('drinks.txt')

# %%
# Visualização

df.head()
# Out:
#        country  beer_servings  spirit_servings  wine_servings  \
# 0  Afghanistan              0                0              0
# 1      Albania             89              132             54
# 2      Algeria             25                0             14
# 3      Andorra            245              138            312
# 4       Angola            217               57             45
#
#    total_litres_of_pure_alcohol
# 0                           0.0
# 1                           4.9
# 2                           0.7
# 3                          12.4
# 4                           5.9

# %%
# Distribuições conjuntas

sns.pairplot(df, kind='reg')

# %% [markdown]
# # 1. Qual a média e desvio padrão do consumo de cerveja, licor, vinho e total de álcool?

# %%
df.describe()
# Out:
#        beer_servings  spirit_servings  wine_servings  \
# count     193.000000       193.000000     193.000000
# mean      106.160622        80.994819      49.450777
# std       101.143103        88.284312      79.697598
# min         0.000000         0.000000       0.000000
# 25%        20.000000         4.000000       1.000000
# 50%        76.000000        56.000000       8.000000
# 75%       188.000000       128.000000      59.000000
# max       376.000000       438.000000     370.000000
#
#        total_litres_of_pure_alcohol
# count                    193.000000
# mean                       4.717098
# std                        3.773298
# min                        0.000000
# 25%                        1.300000
# 50%                        4.200000
# 75%                        7.200000
# max                       14.400000

# %% [markdown]
# - Média do consumo de cerveja = 106.160622
# - Desvio padrão do consumo de cerveja = 101.143103
#
# - Média do consumo de licor = 80.994819
# - Desvio padrão do consumo de licor = 88.284312
#
# - Média do consumo de vinho = 49.450777
# - Desvio padrão do consumo de vinho = 79.697598
#
# - Média do consumo total de álcool = 4.717098
# - Desvio padrão do consumo total de álcool = 3.773298

# %% [markdown]
# # 2. Qual o consumo de licor na França?

# %%
df[df['country'] == 'France']
# Out:
#    country  beer_servings  spirit_servings  wine_servings  \
# 61  France            127              151            370
#
#     total_litres_of_pure_alcohol
# 61                          11.8

# %% [markdown]
# O consumo de licor na França foi de 151 doses.

# %% [markdown]
# # 3. Quais os 5 países nos quais se consome mais cerveja?

# %%
df.sort_values(by='beer_servings', ascending = False).head()
# Out:
#             country  beer_servings  spirit_servings  wine_servings  \
# 117         Namibia            376                3              1
# 45   Czech Republic            361              170            134
# 62            Gabon            347               98             59
# 65          Germany            346              117            175
# 98        Lithuania            343              244             56
#
#      total_litres_of_pure_alcohol
# 117                           6.8
# 45                           11.8
# 62                            8.9
# 65                           11.3
# 98                           12.9

# %% [markdown]
# Os 5 países nos quais se consome mais cerveja são:
#
# 1. Namibia (Namíbia)
#
# 2. Czech Republic (República Tcheca)
#
# 3. Gabon (Gabão)
#
# 4. Germany (Alemanha)
#
# 5. Lithuania (Lituânia)

# %% [markdown]
# # 4. Quais os 5 países nos quais se consome mais licor?

# %%
df.sort_values(by='spirit_servings', ascending = False).head()
# Out:
#                 country  beer_servings  spirit_servings  wine_servings  \
# 68              Grenada            199              438             28
# 15              Belarus            142              373             42
# 73                Haiti              1              326              1
# 141  Russian Federation            247              326             73
# 144           St. Lucia            171              315             71
#
#      total_litres_of_pure_alcohol
# 68                           11.9
# 15                           14.4
# 73                            5.9
# 141                          11.5
# 144                          10.1

# %% [markdown]
# Os 5 países nos quais se consome mais licor são:
#
# 1. Grenada (Granada)
#
# 2. Belarus (Bielorrússia)
#
# 3. Haiti
#
# 4. Russian Federation (Federação Russa)
#
# 5. St. Lucia (Santa Lúcia)

# %% [markdown]
# # 5. Quais os 5 países nos quais se consome mais vinho?

# %%
df.sort_values(by='wine_servings', ascending = False).head()
# Out:
#          country  beer_servings  spirit_servings  wine_servings  \
# 61        France            127              151            370
# 136     Portugal            194               67            339
# 3        Andorra            245              138            312
# 166  Switzerland            185              100            280
# 48       Denmark            224               81            278
#
#      total_litres_of_pure_alcohol
# 61                           11.8
# 136                          11.0
# 3                            12.4
# 166                          10.2
# 48                           10.4

# %% [markdown]
# Os 5 países nos quais se consome mais vinho são:
#
# 1. France (França)
#
# 2. Portugal
#
# 3. Andorra
#
# 4. Switzerland (Suíça)
#
# 5. Denmark (Dinamarca)

# %% [markdown]
# # 6. Quais os países nos quais o consumo de cerveja está acima da média?

# %% [markdown]
# A média do consumo de cerveja é de 106.160622

# %% [markdown]
# Todos os países como consumo de cerveja está acima da média:

# %%
df[df['beer_servings'] > 106.160622]
# Out:
#             country  beer_servings  spirit_servings  wine_servings  \
# 3           Andorra            245              138            312
# 4            Angola            217               57             45
# 6         Argentina            193               25            221
# 8         Australia            261               72            212
# 9           Austria            279               75            191
# ..              ...            ...              ...            ...
# 182  United Kingdom            219              126            195
# 184             USA            249              158             84
# 185         Uruguay            115               35            220
# 188       Venezuela            333              100              3
# 189         Vietnam            111                2              1
#
#      total_litres_of_pure_alcohol
# 3                            12.4
# 4                             5.9
# 6                             8.3
# ...

# %% [markdown]
# Por resultar em muitos países com o consumo de cerveja acima da média, seguem abaixo os 5 primeiros países com o consumo de cerveja acima da média:

# %%
df[df['beer_servings'] > 106.160622].sort_values(by='beer_servings', ascending = False).head()
# Out:
#             country  beer_servings  spirit_servings  wine_servings  \
# 117         Namibia            376                3              1
# 45   Czech Republic            361              170            134
# 62            Gabon            347               98             59
# 65          Germany            346              117            175
# 135          Poland            343              215             56
#
#      total_litres_of_pure_alcohol
# 117                           6.8
# 45                           11.8
# 62                            8.9
# 65                           11.3
# 135                          10.9

# %% [markdown]
# 1. Namibia (Namíbia)
#
# 2. Czech Republic (República Tcheca)
#
# 3. Gabon (Gabão)
#
# 4. Germany (Alemanha)
#
# 5. Poland (Polônia)

# %% [markdown]
# # 7. Quais países nos quais o consumo total de álcool está acima do Brasil, em ordem crescente?

# %%
df[df['country'] == 'Brazil']
# Out:
#    country  beer_servings  spirit_servings  wine_servings  \
# 23  Brazil            245              145             16
#
#     total_litres_of_pure_alcohol
# 23                           7.2

# %% [markdown]
# O consumo total de álcool no Brasil = 7.2 litros

# %% [markdown]
# Os países nos quais o consumo total de álcool está acima do Brasil:

# %%
df[df['total_litres_of_pure_alcohol'] > 7.2]
# Out:
#                 country  beer_servings  spirit_servings  wine_servings  \
# 3               Andorra            245              138            312
# 6             Argentina            193               25            221
# 8             Australia            261               72            212
# 9               Austria            279               75            191
# 15              Belarus            142              373             42
# 16              Belgium            295               84            212
# 25             Bulgaria            231              252             94
# 32               Canada            240              122            100
# 35                Chile            130              124            172
# 42              Croatia            230               87            254
# 44               Cyprus            192              154            113
# 45       Czech Republic            361              170            134
# ...

# %% [markdown]
# Países nos quais o consumo total de álcool está acima do Brasil, em ordem crescente:

# %%
df[df['total_litres_of_pure_alcohol'] > 7.2].sort_values(by='total_litres_of_pure_alcohol', ascending = True).head()
# Out:
#                country  beer_servings  spirit_servings  wine_servings  \
# 132           Paraguay            213              117             74
# 35               Chile            130              124            172
# 188          Venezuela            333              100              3
# 143  St. Kitts & Nevis            194              205             32
# 159       South Africa            225               76             81
#
#      total_litres_of_pure_alcohol
# 132                           7.3
# 35                            7.6
# 188                           7.7
# 143                           7.7
# 159                           8.2

# %% [markdown]
# Os 5 primeiros países nos quais o consumo total de álcool está acima do Brasil, em ordem crescente:
#
# 1. Paraguay (Paraguai)
#
# 2. Chile
#
# 3. Venezuela
#
# 4. St. Kitts & Nevis (São Cristóvão e Névis)
#
# 5. South Africa (África do Sul)

# %% [markdown]
# # 8. De acordo com o conjunto de dados, 5 países com o consumo total de álcool igual a zero

# %%
sem_alcool = df.total_litres_of_pure_alcohol == 0
print(df.country[sem_alcool])
# Out:
# 0           Afghanistan
# 13           Bangladesh
# 46          North Korea
# 79                 Iran
# 90               Kuwait
# 97                Libya
# 103            Maldives
# 106    Marshall Islands
# 107          Mauritania
# 111              Monaco
# 128            Pakistan
# 147          San Marino
# 158             Somalia
# Name: country, dtype: object

# %%
df[df['total_litres_of_pure_alcohol'] == 0].sort_values(by='total_litres_of_pure_alcohol', ascending = False).head()
# Out:
#         country  beer_servings  spirit_servings  wine_servings  \
# 0   Afghanistan              0                0              0
# 13   Bangladesh              0                0              0
# 46  North Korea              0                0              0
# 79         Iran              0                0              0
# 90       Kuwait              0                0              0
#
#     total_litres_of_pure_alcohol
# 0                            0.0
# 13                           0.0
# 46                           0.0
# 79                           0.0
# 90                           0.0

# %% [markdown]
# 5 países com o consumo total de álcool igual a zero, de acordo com esse conjunto de dados:
#
# 1. Afghanistan (Afeganistão)
#
# 2. Bangladesh
#
# 3. North Korea (Coréia do Norte)
#
# 4. Iran (Irã)
#
# 5. Kuwait

# %% [markdown]
# # 9. Gráfico com os 10 maiores consumidores de álcool

# %%
mais_alcool = df.sort_values(by='total_litres_of_pure_alcohol', ascending = False)
mais_alcool[:10]
# Out:
#                 country  beer_servings  spirit_servings  wine_servings  \
# 15              Belarus            142              373             42
# 98            Lithuania            343              244             56
# 3               Andorra            245              138            312
# 68              Grenada            199              438             28
# 45       Czech Republic            361              170            134
# 61               France            127              151            370
# 141  Russian Federation            247              326             73
# 81              Ireland            313              118            165
# 155            Slovakia            196              293            116
# 99           Luxembourg            236              133            271
#
#      total_litres_of_pure_alcohol
# 15                           14.4
# 98                           12.9
# 3                            12.4
# 68                           11.9
# ...

# %%
plt.figure(figsize=(8,8))
plt.title('Os 10 maiores consumidores de álcool')
sns.barplot(y="country", x="total_litres_of_pure_alcohol", color = 'b', ci = None, data=mais_alcool[:10])
plt.xlabel('Litros totais de álcool puro')
plt.ylabel('País')
plt.show()
